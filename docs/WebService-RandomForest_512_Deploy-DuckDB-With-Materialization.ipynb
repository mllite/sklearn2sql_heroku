# %%
import numpy as np
import pandas as pd
import sqlalchemy as sa
import pickle, json, requests, base64

import time
from datetime import datetime

# %% [markdown]
# # Scikit-Learn Model Deployment Use Case
#
# In this case, we will build a very large ensemble model (here, Random Foreast with 512 trees) on a digits dataset  (not very original !!!) and generate a SQL code for deployment using the web service.
#
# We then execute the SQL code on a local database (postgresql) and compare the SQL execution result with scikit-learn predict/predict_proba/.predict_log_proba result.
#
# Both results are stored in pandas dataframes.

# %% [markdown]
# ## Build a scikit-learn model

# %%
from sklearn import datasets

digits = datasets.load_digits()
X = digits.data
n_classes = len(digits.target_names)

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=512, max_depth=7, min_samples_leaf=30, random_state = 1960)
clf.fit(digits.data, digits.target)
# Out:
# RandomForestClassifier(max_depth=7, min_samples_leaf=30, n_estimators=512,
#                        random_state=1960)

# %%
#clf.__dict__

# %% [markdown]
# ## Generate SQL Code from the Model

# %%
def test_ws_sql_gen(pickle_data):
    WS_URL="http://localhost:1888/model"
    b64_data = base64.b64encode(pickle_data).decode('utf-8')
    data={"Name":"model1", "PickleData":b64_data , "SQLDialect":"duckdb"}
    r = requests.post(WS_URL, json=data)
    #print(r.__dict__)
    content = r.json()
    # print(content)
    lSQL = content["model"]["SQLGenrationResult"][0]["SQL"]
    return lSQL;

# %%
pickle_data = pickle.dumps(clf)
lSQL1 = test_ws_sql_gen(pickle_data)
(lTempSQLs , lFinalSQL1 , lFinalSQL2) = lSQL1
lSQLs = []
for t in lTempSQLs:
    (name, lCreateTableSQL , lCreateIndexSQL, lInsertSQL) = t
    lSQLs = lSQLs + [lCreateTableSQL , lCreateIndexSQL, lInsertSQL] 
lSQLs = lSQLs + [lFinalSQL1]
lSQLs = [t for t in lSQLs if t is not None]
lSQLs = [t.replace("DOUBLE_PRECISION", "DOUBLE") for t in lSQLs]

with open('data/digits_64_features_RF_512_DuckDB_with_materialization.sql', 'w') as f:
    for s in lSQLs:
        print("XXXXXXXXXXXXXXXXXXXXXXXXX" , s[:50] , s[-50:])
        f.write(s + ";\n\n")

for lSQL in lSQLs:
    N = len(lSQL)
    P = 60
    print(lSQL[0:P] + "..." + lSQL[N//2:(N//2 + P)] + "..." + lSQL[-P:])
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_BFD3Q6
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup" AS
# (SELECT "ADS"."KEY" AS " OM "RF_Model_9") AS "RF_esu_0") AS "RF_B0") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_1NXVGZ
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_10" AS
# (SELECT "ADS"."KEY" A M "RF_Model_19") AS "RF_esu_1") AS "RF_B1") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_W12XMU
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_20" AS
# (SELECT "ADS"."KEY" A M "RF_Model_29") AS "RF_esu_2") AS "RF_B2") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_XCA2TC
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_30" AS
# (SELECT "ADS"."KEY" A M "RF_Model_39") AS "RF_esu_3") AS "RF_B3") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_VPUHY8
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_40" AS
# (SELECT "ADS"."KEY" A M "RF_Model_49") AS "RF_esu_4") AS "RF_B4") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_7Z50A2
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_50" AS
# (SELECT "ADS"."KEY" A M "RF_Model_59") AS "RF_esu_5") AS "RF_B5") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_V1A5KC
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_60" AS
# (SELECT "ADS"."KEY" A M "RF_Model_69") AS "RF_esu_6") AS "RF_B6") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_ZXE0FH
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_70" AS
# (SELECT "ADS"."KEY" A M "RF_Model_79") AS "RF_esu_7") AS "RF_B7") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_K9PUID
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_80" AS
# (SELECT "ADS"."KEY" A M "RF_Model_89") AS "RF_esu_8") AS "RF_B8") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_BG784J
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_90" AS
# (SELECT "ADS"."KEY" A M "RF_Model_99") AS "RF_esu_9") AS "RF_B9") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_6CMCOO
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_100" AS
# (SELECT "ADS"."KEY"  RF_Model_109") AS "RF_esu_10") AS "RF_B10") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_TNCUB8
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_110" AS
# (SELECT "ADS"."KEY"  RF_Model_119") AS "RF_esu_11") AS "RF_B11") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_TB1S1H
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_120" AS
# (SELECT "ADS"."KEY"  RF_Model_129") AS "RF_esu_12") AS "RF_B12") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_EP0YZ1
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_130" AS
# (SELECT "ADS"."KEY"  RF_Model_139") AS "RF_esu_13") AS "RF_B13") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_AR98O5
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_140" AS
# (SELECT "ADS"."KEY"  RF_Model_149") AS "RF_esu_14") AS "RF_B14") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_KUXITM
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_150" AS
# (SELECT "ADS"."KEY"  RF_Model_159") AS "RF_esu_15") AS "RF_B15") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_4JXYLL
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_160" AS
# (SELECT "ADS"."KEY"  RF_Model_169") AS "RF_esu_16") AS "RF_B16") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002034_0PDCBM
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_170" AS
# (SELECT "ADS"."KEY"  RF_Model_179") AS "RF_esu_17") AS "RF_B17") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_AQPZ4Y
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_180" AS
# (SELECT "ADS"."KEY"  RF_Model_189") AS "RF_esu_18") AS "RF_B18") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_Q7IXGF
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_190" AS
# (SELECT "ADS"."KEY"  RF_Model_199") AS "RF_esu_19") AS "RF_B19") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_WL89SZ
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_200" AS
# (SELECT "ADS"."KEY"  RF_Model_209") AS "RF_esu_20") AS "RF_B20") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_KYCACI
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_210" AS
# (SELECT "ADS"."KEY"  RF_Model_219") AS "RF_esu_21") AS "RF_B21") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_K0YCTJ
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_220" AS
# (SELECT "ADS"."KEY"  RF_Model_229") AS "RF_esu_22") AS "RF_B22") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_XZNU9C
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_230" AS
# (SELECT "ADS"."KEY"  RF_Model_239") AS "RF_esu_23") AS "RF_B23") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_4ZOM8E
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_240" AS
# (SELECT "ADS"."KEY"  RF_Model_249") AS "RF_esu_24") AS "RF_B24") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_LU36JF
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_250" AS
# (SELECT "ADS"."KEY"  RF_Model_259") AS "RF_esu_25") AS "RF_B25") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_D9A3J9
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_260" AS
# (SELECT "ADS"."KEY"  RF_Model_269") AS "RF_esu_26") AS "RF_B26") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_F0E056
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_270" AS
# (SELECT "ADS"."KEY"  RF_Model_279") AS "RF_esu_27") AS "RF_B27") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_2P8IPI
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_280" AS
# (SELECT "ADS"."KEY"  RF_Model_289") AS "RF_esu_28") AS "RF_B28") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_H5ULKJ
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_290" AS
# (SELECT "ADS"."KEY"  RF_Model_299") AS "RF_esu_29") AS "RF_B29") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_2XBGUB
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_300" AS
# (SELECT "ADS"."KEY"  RF_Model_309") AS "RF_esu_30") AS "RF_B30") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_8397AO
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_310" AS
# (SELECT "ADS"."KEY"  RF_Model_319") AS "RF_esu_31") AS "RF_B31") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_DRDDTS
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_320" AS
# (SELECT "ADS"."KEY"  RF_Model_329") AS "RF_esu_32") AS "RF_B32") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_WKDJFA
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_330" AS
# (SELECT "ADS"."KEY"  RF_Model_339") AS "RF_esu_33") AS "RF_B33") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_7QPJ9B
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_340" AS
# (SELECT "ADS"."KEY"  RF_Model_349") AS "RF_esu_34") AS "RF_B34") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_BHKGTI
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_350" AS
# (SELECT "ADS"."KEY"  RF_Model_359") AS "RF_esu_35") AS "RF_B35") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_TOGZ01
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_360" AS
# (SELECT "ADS"."KEY"  RF_Model_369") AS "RF_esu_36") AS "RF_B36") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_72PXFV
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_370" AS
# (SELECT "ADS"."KEY"  RF_Model_379") AS "RF_esu_37") AS "RF_B37") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_RYUK13
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_380" AS
# (SELECT "ADS"."KEY"  RF_Model_389") AS "RF_esu_38") AS "RF_B38") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_7ATFIG
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_390" AS
# (SELECT "ADS"."KEY"  RF_Model_399") AS "RF_esu_39") AS "RF_B39") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_VIYHT0
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_400" AS
# (SELECT "ADS"."KEY"  RF_Model_409") AS "RF_esu_40") AS "RF_B40") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_BJL7H9
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_410" AS
# (SELECT "ADS"."KEY"  RF_Model_419") AS "RF_esu_41") AS "RF_B41") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_0OTRQP
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_420" AS
# (SELECT "ADS"."KEY"  RF_Model_429") AS "RF_esu_42") AS "RF_B42") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_62BRUQ
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_430" AS
# (SELECT "ADS"."KEY"  RF_Model_439") AS "RF_esu_43") AS "RF_B43") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_EJ1ZUG
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_440" AS
# (SELECT "ADS"."KEY"  RF_Model_449") AS "RF_esu_44") AS "RF_B44") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_84L5PY
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_450" AS
# (SELECT "ADS"."KEY"  RF_Model_459") AS "RF_esu_45") AS "RF_B45") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_8U7CB6
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_460" AS
# (SELECT "ADS"."KEY"  RF_Model_469") AS "RF_esu_46") AS "RF_B46") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_EW4O2H
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_470" AS
# (SELECT "ADS"."KEY"  RF_Model_479") AS "RF_esu_47") AS "RF_B47") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_IE1NQL
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_480" AS
# (SELECT "ADS"."KEY"  RF_Model_489") AS "RF_esu_48") AS "RF_B48") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_AK3JTN
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_490" AS
# (SELECT "ADS"."KEY"  RF_Model_499") AS "RF_esu_49") AS "RF_B49") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_HGNTJX
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_500" AS
# (SELECT "ADS"."KEY"  RF_Model_509") AS "RF_esu_50") AS "RF_B50") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_F0OOD2
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "DT_node_lookup_510" AS
# (SELECT "ADS"."KEY"  RF_Model_511") AS "RF_esu_51") AS "RF_B51") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX
# CREATE TEMPORARY TABLE "TMP_20221025002035_TCLMKA
# 	PRIMARY KEY ("KEY")
# )
#
#  ON COMMIT PRESERVE ROWS
# XXXXXXXXXXXXXXXXXXXXXXXXX CREATE INDEX "ix_TMP_20221025002035_TCLMKAY_RF_avg EY" ON "TMP_20221025002035_TCLMKAY_RF_avg" ("KEY")
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH "RF_Union" AS
# (SELECT "RF_EnsembleUnion"."KE P BY "RF_Union"."KEY") AS "T") AS "RF_avg") AS "T"
# XXXXXXXXXXXXXXXXXXXXXXXXX WITH orig_cte AS
# (SELECT "RF_avg"."KEY" AS "KEY", e."max_Proba" AS "DecisionProba"
# FROM arg_max_cte
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_BFD3Q63_RF_B0" (...,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DOU...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE...LL SELECT 52 AS nid, 0.0 AS "P_0", 0.0 AS "P_1", 0.0 AS "P_2...oba_9"
# FROM "RF_Model_9") AS "RF_esu_0") AS "RF_B0") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_1NXVGZY_RF_B1" (...,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DOU...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_10" AS
# (SELECT "ADS"."KEY" AS "KEY", C...S "DP" UNION ALL SELECT 38 AS nid, 0.0 AS "P_0", 0.0 AS "P_1...ba_9"
# FROM "RF_Model_19") AS "RF_esu_1") AS "RF_B1") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_W12XMUT_RF_B2" (...,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DOU...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_20" AS
# (SELECT "ADS"."KEY" AS "KEY", C...2857142857142857 AS "P_7", 0.14285714285714285 AS "P_8", 0.0...ba_9"
# FROM "RF_Model_29") AS "RF_esu_2") AS "RF_B2") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_XCA2TCM_RF_B3" (...,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DOU...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_30" AS
# (SELECT "ADS"."KEY" AS "KEY", C...869565216 AS "P_5", 0.0 AS "P_6", 0.11594202898550725 AS "P_...ba_9"
# FROM "RF_Model_39") AS "RF_esu_3") AS "RF_B3") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_VPUHY8C_RF_B4" (...,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DOU...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_40" AS
# (SELECT "ADS"."KEY" AS "KEY", C...660377 AS "P_1", 0.0 AS "P_2", 0.0 AS "P_3", 0.9433962264150...ba_9"
# FROM "RF_Model_49") AS "RF_esu_4") AS "RF_B4") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_7Z50A21_RF_B5" (...,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DOU...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_50" AS
# (SELECT "ADS"."KEY" AS "KEY", C...0.0 AS "P_9", 3 AS "D", 0.8589743589743589 AS "DP" UNION ALL...ba_9"
# FROM "RF_Model_59") AS "RF_esu_5") AS "RF_B5") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_V1A5KCT_RF_B6" (...,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DOU...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_60" AS
# (SELECT "ADS"."KEY" AS "KEY", C...7451 AS "P_8", 0.0784313725490196 AS "P_9", 2 AS "D", 0.6862...ba_9"
# FROM "RF_Model_69") AS "RF_esu_6") AS "RF_B6") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_ZXE0FHB_RF_B7" (...,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DOU...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_70" AS
# (SELECT "ADS"."KEY" AS "KEY", C...P") AS "Values"),
# "DT_Output_75" AS
# (SELECT "DT_node_looku...ba_9"
# FROM "RF_Model_79") AS "RF_esu_7") AS "RF_B7") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_K9PUIDO_RF_B8" (...,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DOU...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_80" AS
# (SELECT "ADS"."KEY" AS "KEY", C...S "P_9", 0 AS "D", 1.0 AS "DP") AS "Values"),
# "DT_Output_85...ba_9"
# FROM "RF_Model_89") AS "RF_esu_8") AS "RF_B8") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_BG784JY_RF_B9" (...,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DOU...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_90" AS
# (SELECT "ADS"."KEY" AS "KEY", C..._8", 0.05172413793103448 AS "P_9", 7 AS "D", 0.7413793103448...ba_9"
# FROM "RF_Model_99") AS "RF_esu_9") AS "RF_B9") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_6CMCOO1_RF_B10" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_100" AS
# (SELECT "ADS"."KEY" AS "KEY", ..."P_1", 0.3870967741935484 AS "P_2", 0.15591397849462366 AS "...9"
# FROM "RF_Model_109") AS "RF_esu_10") AS "RF_B10") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_TNCUB8A_RF_B11" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_110" AS
# (SELECT "ADS"."KEY" AS "KEY", ...1025641 AS "P_8", 0.0 AS "P_9", 2 AS "D", 0.7564102564102564...9"
# FROM "RF_Model_119") AS "RF_esu_11") AS "RF_B11") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_TB1S1HY_RF_B12" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_120" AS
# (SELECT "ADS"."KEY" AS "KEY", ...15873015872 AS "P_3", 0.0 AS "P_4", 0.031746031746031744 AS ...9"
# FROM "RF_Model_129") AS "RF_esu_12") AS "RF_B12") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_EP0YZ16_RF_B13" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_130" AS
# (SELECT "ADS"."KEY" AS "KEY", ..." UNION ALL SELECT 58 AS nid, 0.0 AS "P_0", 0.28846153846153...9"
# FROM "RF_Model_139") AS "RF_esu_13") AS "RF_B13") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_AR98O5F_RF_B14" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_140" AS
# (SELECT "ADS"."KEY" AS "KEY", ...S "D", 0.88 AS "DP" UNION ALL SELECT 40 AS nid, 0.0 AS "P_0"...9"
# FROM "RF_Model_149") AS "RF_esu_14") AS "RF_B14") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_KUXITMH_RF_B15" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_150" AS
# (SELECT "ADS"."KEY" AS "KEY", ...6666666666 AS "P_4", 0.12222222222222222 AS "P_5", 0.0444444...9"
# FROM "RF_Model_159") AS "RF_esu_15") AS "RF_B15") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_4JXYLLG_RF_B16" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_160" AS
# (SELECT "ADS"."KEY" AS "KEY", ... 0.8688524590163934 AS "P_7", 0.0 AS "P_8", 0.0 AS "P_9", 7 ...9"
# FROM "RF_Model_169") AS "RF_esu_16") AS "RF_B16") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002034_0PDCBMY_RF_B17" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_170" AS
# (SELECT "ADS"."KEY" AS "KEY", ...814814814814815 AS "P_6", 0.0 AS "P_7", 0.0 AS "P_8", 0.0 AS...9"
# FROM "RF_Model_179") AS "RF_esu_17") AS "RF_B17") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_AQPZ4YQ_RF_B18" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_180" AS
# (SELECT "ADS"."KEY" AS "KEY", ...", 0.018518518518518517 AS "P_3", 0.0 AS "P_4", 0.0185185185...9"
# FROM "RF_Model_189") AS "RF_esu_18") AS "RF_B18") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_Q7IXGF8_RF_B19" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_190" AS
# (SELECT "ADS"."KEY" AS "KEY", ...P_1", 0.0 AS "P_2", 0.0 AS "P_3", 0.0 AS "P_4", 0.0392156862...9"
# FROM "RF_Model_199") AS "RF_esu_19") AS "RF_B19") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_WL89SZ9_RF_B20" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_200" AS
# (SELECT "ADS"."KEY" AS "KEY", ... "P_4", 0.0 AS "P_5", 0.0 AS "P_6", 0.03278688524590164 AS "...9"
# FROM "RF_Model_209") AS "RF_esu_20") AS "RF_B20") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_KYCACIP_RF_B21" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_210" AS
# (SELECT "ADS"."KEY" AS "KEY", ...AS "P_6", "DT_node_data_215"."P_7" AS "P_7", "DT_node_data_2...9"
# FROM "RF_Model_219") AS "RF_esu_21") AS "RF_B21") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_K0YCTJ0_RF_B22" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_220" AS
# (SELECT "ADS"."KEY" AS "KEY", ...AS "P_1", 0.04395604395604396 AS "P_2", 0.5824175824175825 A...9"
# FROM "RF_Model_229") AS "RF_esu_22") AS "RF_B22") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_XZNU9CS_RF_B23" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_230" AS
# (SELECT "ADS"."KEY" AS "KEY", ...AS "P_6", 0.0 AS "P_7", 0.05454545454545454 AS "P_8", 0.0363...9"
# FROM "RF_Model_239") AS "RF_esu_23") AS "RF_B23") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_4ZOM8EK_RF_B24" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_240" AS
# (SELECT "ADS"."KEY" AS "KEY", ...22223 AS "P_4", 0.06666666666666667 AS "P_5", 0.022222222222...9"
# FROM "RF_Model_249") AS "RF_esu_24") AS "RF_B24") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_LU36JFN_RF_B25" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_250" AS
# (SELECT "ADS"."KEY" AS "KEY", ...P_6", 0.05357142857142857 AS "P_7", 0.03571428571428571 AS "...9"
# FROM "RF_Model_259") AS "RF_esu_25") AS "RF_B25") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_D9A3J97_RF_B26" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_260" AS
# (SELECT "ADS"."KEY" AS "KEY", ...3333333334 AS "P_7", 0.0 AS "P_8", 0.0 AS "P_9", 3 AS "D", 0...9"
# FROM "RF_Model_269") AS "RF_esu_26") AS "RF_B26") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_F0E056E_RF_B27" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_270" AS
# (SELECT "ADS"."KEY" AS "KEY", ...0 AS "P_6", 0.0 AS "P_7", 0.0 AS "P_8", 0.0 AS "P_9", 4 AS "...9"
# FROM "RF_Model_279") AS "RF_esu_27") AS "RF_B27") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_2P8IPIK_RF_B28" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_280" AS
# (SELECT "ADS"."KEY" AS "KEY", ... 0.0 AS "P_0", 0.09259259259259259 AS "P_1", 0.0 AS "P_2", 0...9"
# FROM "RF_Model_289") AS "RF_esu_28") AS "RF_B28") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_H5ULKJ3_RF_B29" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_290" AS
# (SELECT "ADS"."KEY" AS "KEY", ..., 0.0 AS "P_2", 0.0 AS "P_3", 0.42857142857142855 AS "P_4", ...9"
# FROM "RF_Model_299") AS "RF_esu_29") AS "RF_B29") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_2XBGUBF_RF_B30" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_300" AS
# (SELECT "ADS"."KEY" AS "KEY", ...ALL SELECT 47 AS nid, 0.0 AS "P_0", 0.0 AS "P_1", 0.0 AS "P_...9"
# FROM "RF_Model_309") AS "RF_esu_30") AS "RF_B30") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_8397AOI_RF_B31" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_310" AS
# (SELECT "ADS"."KEY" AS "KEY", ...813953488 AS "P_9", 4 AS "D", 0.37209302325581395 AS "DP" UN...9"
# FROM "RF_Model_319") AS "RF_esu_31") AS "RF_B31") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_DRDDTSI_RF_B32" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_320" AS
# (SELECT "ADS"."KEY" AS "KEY", ...0.03389830508474576 AS "P_8", 0.0 AS "P_9", 5 AS "D", 0.4406...9"
# FROM "RF_Model_329") AS "RF_esu_32") AS "RF_B32") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_WKDJFAZ_RF_B33" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_330" AS
# (SELECT "ADS"."KEY" AS "KEY", ..._data_335"."D" AS "D", "DT_node_data_335"."DP" AS "DP"
# FROM...9"
# FROM "RF_Model_339") AS "RF_esu_33") AS "RF_B33") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_7QPJ9BP_RF_B34" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_340" AS
# (SELECT "ADS"."KEY" AS "KEY", ...NION ALL SELECT 47 AS nid, 0.0 AS "P_0", 0.05 AS "P_1", 0.05...9"
# FROM "RF_Model_349") AS "RF_esu_34") AS "RF_B34") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_BHKGTIU_RF_B35" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_350" AS
# (SELECT "ADS"."KEY" AS "KEY", ...093023255813954 AS "P_8", 0.13953488372093023 AS "P_9", 3 AS...9"
# FROM "RF_Model_359") AS "RF_esu_35") AS "RF_B35") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_TOGZ01Q_RF_B36" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_360" AS
# (SELECT "ADS"."KEY" AS "KEY", ..._8" AS "P_8", "DT_node_data_365"."P_9" AS "P_9", "DT_node_da...9"
# FROM "RF_Model_369") AS "RF_esu_36") AS "RF_B36") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_72PXFVK_RF_B37" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_370" AS
# (SELECT "ADS"."KEY" AS "KEY", ...P_3", 0.0 AS "P_4", 0.019230769230769232 AS "P_5", 0.0384615...9"
# FROM "RF_Model_379") AS "RF_esu_37") AS "RF_B37") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_RYUK137_RF_B38" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_380" AS
# (SELECT "ADS"."KEY" AS "KEY", ...69696969697 AS "P_0", 0.12121212121212122 AS "P_1", 0.0 AS "...9"
# FROM "RF_Model_389") AS "RF_esu_38") AS "RF_B38") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_7ATFIGG_RF_B39" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_390" AS
# (SELECT "ADS"."KEY" AS "KEY", ... "P_7", 0.01694915254237288 AS "P_8", 0.8813559322033898 AS ...9"
# FROM "RF_Model_399") AS "RF_esu_39") AS "RF_B39") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_VIYHT0K_RF_B40" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_400" AS
# (SELECT "ADS"."KEY" AS "KEY", ...4 AS "D", 0.6521739130434783 AS "DP" UNION ALL SELECT 51 AS ...9"
# FROM "RF_Model_409") AS "RF_esu_40") AS "RF_B40") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_BJL7H90_RF_B41" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_410" AS
# (SELECT "ADS"."KEY" AS "KEY", ...0", 0.3392857142857143 AS "P_1", 0.6607142857142857 AS "P_2"...9"
# FROM "RF_Model_419") AS "RF_esu_41") AS "RF_B41") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_0OTRQP1_RF_B42" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_420" AS
# (SELECT "ADS"."KEY" AS "KEY", ....06 AS "P_1", 0.0 AS "P_2", 0.0 AS "P_3", 0.02 AS "P_4", 0.0...9"
# FROM "RF_Model_429") AS "RF_esu_42") AS "RF_B42") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_62BRUQI_RF_B43" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_430" AS
# (SELECT "ADS"."KEY" AS "KEY", ...S "P_3", 0.0 AS "P_4", 0.0 AS "P_5", 0.0 AS "P_6", 0.0 AS "P...9"
# FROM "RF_Model_439") AS "RF_esu_43") AS "RF_B43") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_EJ1ZUGJ_RF_B44" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_440" AS
# (SELECT "ADS"."KEY" AS "KEY", ...S "P_4", 0.2553191489361702 AS "P_5", 0.0 AS "P_6", 0.0 AS "...9"
# FROM "RF_Model_449") AS "RF_esu_44") AS "RF_B44") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_84L5PY9_RF_B45" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_450" AS
# (SELECT "ADS"."KEY" AS "KEY", ...2593 AS "DP" UNION ALL SELECT 48 AS nid, 0.0 AS "P_0", 0.068...9"
# FROM "RF_Model_459") AS "RF_esu_45") AS "RF_B45") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_8U7CB6F_RF_B46" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_460" AS
# (SELECT "ADS"."KEY" AS "KEY", ...653061 AS "P_3", 0.0 AS "P_4", 0.2653061224489796 AS "P_5", ...9"
# FROM "RF_Model_469") AS "RF_esu_46") AS "RF_B46") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_EW4O2HF_RF_B47" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_470" AS
# (SELECT "ADS"."KEY" AS "KEY", ...2 AS "P_5", 0.0 AS "P_6", 0.0 AS "P_7", 0.04950495049504951 ...9"
# FROM "RF_Model_479") AS "RF_esu_47") AS "RF_B47") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_IE1NQLH_RF_B48" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_480" AS
# (SELECT "ADS"."KEY" AS "KEY", ...", 0.0 AS "P_5", 0.0 AS "P_6", 0.8888888888888888 AS "P_7", ...9"
# FROM "RF_Model_489") AS "RF_esu_48") AS "RF_B48") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_AK3JTNP_RF_B49" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_490" AS
# (SELECT "ADS"."KEY" AS "KEY", ...", 1.0 AS "P_6", 0.0 AS "P_7", 0.0 AS "P_8", 0.0 AS "P_9", 6...9"
# FROM "RF_Model_499") AS "RF_esu_49") AS "RF_B49") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_HGNTJXS_RF_B50" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_500" AS
# (SELECT "ADS"."KEY" AS "KEY", ... 53 AS nid, 0.0 AS "P_0", 0.0 AS "P_1", 0.07142857142857142 ...9"
# FROM "RF_Model_509") AS "RF_esu_50") AS "RF_B50") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_F0OOD2L_RF_B51" ...E,
# 	"LogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DO...9" DOUBLE,
# 	"LogProba_9" DOUBLE
# )
#
#  ON COMMIT PRESERVE ROWS
# WITH "DT_node_lookup_510" AS
# (SELECT "ADS"."KEY" AS "KEY", ... 0.0 AS "P_8", 0.0 AS "P_9", 0 AS "D", 1.0 AS "DP" UNION ALL...9"
# FROM "RF_Model_511") AS "RF_esu_51") AS "RF_B51") AS "T"
#
# CREATE TEMPORARY TABLE "TMP_20221025002035_TCLMKAY_RF_avg" ...ogProba_4" DOUBLE,
# 	"Score_5" DOUBLE,
# 	"Proba_5" DOUBLE,
# ...9" DOUBLE,
# 	PRIMARY KEY ("KEY")
# )
#
#  ON COMMIT PRESERVE ROWS
# CREATE INDEX "ix_TMP_20221025002035_TCLMKAY_RF_avg_KEY" ON "...KEY" ON "TMP_20221025002035_TCLMKAY_RF_avg" ("KEY")...Y_RF_avg_KEY" ON "TMP_20221025002035_TCLMKAY_RF_avg" ("KEY")
# WITH "RF_Union" AS
# (SELECT "RF_EnsembleUnion"."KEY" AS "KEY...", "RF_B27"."LogProba_7" AS "LogProba_7", "RF_B27"."Score_8"...nion" GROUP BY "RF_Union"."KEY") AS "T") AS "RF_avg") AS "T"
# WITH orig_cte AS
# (SELECT "RF_avg"."KEY" AS "KEY", "RF_avg"....x."Score_8" AS "Score_8", score_max."Score_9" AS "Score_9", ...arg_max_cte."max_Proba" AS "DecisionProba"
# FROM arg_max_cte

# %% [markdown]
# ## Execute the SQL Code

# %%
# save the dataset in a database table

conf = {"memory_limit": "1000mb", "temp_directory" : "", "threads" : 1, "external_threads" : 0}
engine = sa.create_engine("duckdb:///:memory:" , connect_args={"config": conf}, echo=False)
conn = engine.connect()
# conn.execute("PRAGMA threads=1")
# conn.execute("PRAGMA external_threads=1")

lTable = pd.DataFrame(digits.data);
lTable.columns = ['Feature_' + str(c) for c in range(digits.data.shape[1])]
lTable['KEY'] = range(lTable.shape[0])
lTable.to_csv("data/digits.csv", index=False)
lTable.to_sql("INPUT_DATA" , conn,   if_exists='replace', index=False)

print("DUCKDB_VERSION", [x for x in conn.execute("PRAGMA version")])
# Out:
# DUCKDB_VERSION [('0.5.1', '7c111322d')]

# %%
# create temp tables
for lSQL in lSQLs[:-1]:
    conn.exec_driver_sql(lSQL)
sql_output = pd.read_sql(lSQLs[-1] , conn);

sql_output = sql_output.sort_values(by='KEY').reset_index(drop=True)
conn.close()

# %%
sql_output.sample(12, random_state=1960)
# Out:
#        KEY Score_0 Score_1 Score_2 Score_3 Score_4 Score_5 Score_6 Score_7  \
# 1197  1197    None    None    None    None    None    None    None    None
# 913    913    None    None    None    None    None    None    None    None
# 893    893    None    None    None    None    None    None    None    None
# 604    604    None    None    None    None    None    None    None    None
# 743    743    None    None    None    None    None    None    None    None
# 556    556    None    None    None    None    None    None    None    None
# 664    664    None    None    None    None    None    None    None    None
# 195    195    None    None    None    None    None    None    None    None
# 692    692    None    None    None    None    None    None    None    None
# 1589  1589    None    None    None    None    None    None    None    None
# 1194  1194    None    None    None    None    None    None    None    None
# 822    822    None    None    None    None    None    None    None    None
#
#      Score_8  ... LogProba_2  LogProba_3  LogProba_4  LogProba_5  LogProba_6  \
# 1197    None  ...  -3.271224   -2.185342   -3.074713   -1.532286   -3.913458
# 913     None  ...  -2.496320   -2.097181   -3.883939   -2.617019   -3.047992
# 893     None  ...  -2.764154   -2.486125   -4.001539   -0.718490   -4.412884
# 604     None  ...  -3.325013   -4.182968   -2.009558   -1.538349   -1.123425
# 743     None  ...  -5.167743   -5.425719   -0.615005   -3.479554   -4.037963
# 556     None  ...  -1.689932   -2.412699   -3.587378   -4.484135   -2.869010
# 664     None  ...  -3.111373   -2.387851   -3.237153   -2.289746   -2.790281
# 195     None  ...  -3.639786   -4.971824   -3.079982   -4.108785   -0.226434
# 692     None  ...  -3.625768   -3.617052   -3.603747   -0.359531   -3.612624
# 1589    None  ...  -3.479113   -4.513059   -3.068721   -0.702351   -2.655061
# 1194    None  ...  -3.633719   -2.567681   -4.120463   -2.611717   -4.634110
# 822     None  ...  -3.526294   -3.807369   -3.652604   -0.363653   -4.745843
#
#       LogProba_7  LogProba_8  LogProba_9  Decision  DecisionProba
# 1197   -2.400581   -1.469503   -2.246424         8       0.230040
# 913    -3.786127   -0.820853   -2.183164         8       0.440056
# 893    -3.060126   -2.164634   -2.968205         5       0.487488
# 604    -3.581279   -2.308723   -4.636519         6       0.325164
# 743    -1.379316   -3.507207   -3.300613         4       0.540638
# 556    -3.602473   -0.967115   -3.418996         8       0.380178
# 664    -3.369948   -0.969122   -2.358257         8       0.379416
# 195    -5.803139   -3.301036   -5.121011         6       0.797372
# 692    -3.345042   -2.542779   -3.533635         5       0.698004
# 1589   -2.595765   -2.939838   -3.168150         5       0.495419
# 1194   -3.696028   -2.798969   -0.443228         9       0.641961
# 822    -2.786068   -2.546733   -3.290512         5       0.695132
#
# [12 rows x 33 columns]

# %%
sql_output.Decision.value_counts()
# Out:
# 7    197
# 9    186
# 1    184
# 4    180
# 6    179
# 0    178
# 5    176
# 2    175
# 3    175
# 8    167
# Name: Decision, dtype: int64

# %% [markdown]
# ## Scikit-learn Prediction

# %%
skl_outputs = pd.DataFrame()
skl_output_key = pd.DataFrame(list(range(X.shape[0])), columns=['KEY']);
skl_output_score = pd.DataFrame(columns=['Score_' + str(c) for c in range(n_classes)]);
skl_output_proba = pd.DataFrame(clf.predict_proba(X), columns=['Proba_' + str(c) for c in range(n_classes)])
skl_output_log_proba = pd.DataFrame(clf.predict_log_proba(X), columns=['LogProba_' + str(c) for c in range(n_classes)])
skl_output_decision = pd.DataFrame(clf.predict(X), columns=['Decision'])
skl_output = pd.concat([skl_output_key, skl_output_score, skl_output_proba, skl_output_log_proba, skl_output_decision] , axis=1)
skl_output.sample(12, random_state=1960)
# Out:
#        KEY Score_0 Score_1 Score_2 Score_3 Score_4 Score_5 Score_6 Score_7  \
# 1197  1197     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 913    913     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 893    893     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 604    604     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 743    743     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 556    556     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 664    664     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 195    195     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 692    692     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1589  1589     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1194  1194     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 822    822     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      Score_8  ... LogProba_1  LogProba_2  LogProba_3  LogProba_4  LogProba_5  \
# 1197     NaN  ...  -2.239128   -3.271224   -2.185342   -3.074713   -1.532286
# 913      NaN  ...  -3.128394   -2.496320   -2.097181   -3.883939   -2.617019
# 893      NaN  ...  -2.129655   -2.764154   -2.486125   -4.001539   -0.718490
# 604      NaN  ...  -2.750753   -3.325013   -4.182968   -2.009558   -1.538349
# 743      NaN  ...  -3.187762   -5.167743   -5.425719   -0.615005   -3.479554
# 556      NaN  ...  -1.724560   -1.689932   -2.412699   -3.587378   -4.484135
# 664      NaN  ...  -2.673481   -3.111373   -2.387851   -3.237153   -2.289746
# 195      NaN  ...  -3.013571   -3.639786   -4.971824   -3.079982   -4.108785
# 692      NaN  ...  -3.312214   -3.625768   -3.617052   -3.603747   -0.359531
# 1589     NaN  ...  -3.708405   -3.479113   -4.513059   -3.068721   -0.702351
# 1194     NaN  ...  -3.715642   -3.633719   -2.567681   -4.120463   -2.611717
# 822      NaN  ...  -3.242409   -3.526294   -3.807369   -3.652604   -0.363653
#
#       LogProba_6  LogProba_7  LogProba_8  LogProba_9  Decision
# 1197   -3.913458   -2.400581   -1.469503   -2.246424         8
# 913    -3.047992   -3.786127   -0.820853   -2.183164         8
# 893    -4.412884   -3.060126   -2.164634   -2.968205         5
# 604    -1.123425   -3.581279   -2.308723   -4.636519         6
# 743    -4.037963   -1.379316   -3.507207   -3.300613         4
# 556    -2.869010   -3.602473   -0.967115   -3.418996         8
# 664    -2.790281   -3.369948   -0.969122   -2.358257         8
# 195    -0.226434   -5.803139   -3.301036   -5.121011         6
# 692    -3.612624   -3.345042   -2.542779   -3.533635         5
# 1589   -2.655061   -2.595765   -2.939838   -3.168150         5
# 1194   -4.634110   -3.696028   -2.798969   -0.443228         9
# 822    -4.745843   -2.786068   -2.546733   -3.290512         5
#
# [12 rows x 32 columns]

# %% [markdown]
# ## Comparing the SQL and Scikit-learn Predictions

# %%
sql_skl_join = skl_output.join(sql_output , how='left', on='KEY', lsuffix='_skl', rsuffix='_sql')

# %%
sql_skl_join.sample(12, random_state=1960)
# Out:
#       KEY_skl Score_0_skl Score_1_skl Score_2_skl Score_3_skl Score_4_skl  \
# 1197     1197         NaN         NaN         NaN         NaN         NaN
# 913       913         NaN         NaN         NaN         NaN         NaN
# 893       893         NaN         NaN         NaN         NaN         NaN
# 604       604         NaN         NaN         NaN         NaN         NaN
# 743       743         NaN         NaN         NaN         NaN         NaN
# 556       556         NaN         NaN         NaN         NaN         NaN
# 664       664         NaN         NaN         NaN         NaN         NaN
# 195       195         NaN         NaN         NaN         NaN         NaN
# 692       692         NaN         NaN         NaN         NaN         NaN
# 1589     1589         NaN         NaN         NaN         NaN         NaN
# 1194     1194         NaN         NaN         NaN         NaN         NaN
# 822       822         NaN         NaN         NaN         NaN         NaN
#
#      Score_5_skl Score_6_skl Score_7_skl Score_8_skl  ... LogProba_2_sql  \
# 1197         NaN         NaN         NaN         NaN  ...      -3.271224
# 913          NaN         NaN         NaN         NaN  ...      -2.496320
# 893          NaN         NaN         NaN         NaN  ...      -2.764154
# 604          NaN         NaN         NaN         NaN  ...      -3.325013
# 743          NaN         NaN         NaN         NaN  ...      -5.167743
# 556          NaN         NaN         NaN         NaN  ...      -1.689932
# 664          NaN         NaN         NaN         NaN  ...      -3.111373
# 195          NaN         NaN         NaN         NaN  ...      -3.639786
# 692          NaN         NaN         NaN         NaN  ...      -3.625768
# 1589         NaN         NaN         NaN         NaN  ...      -3.479113
# 1194         NaN         NaN         NaN         NaN  ...      -3.633719
# 822          NaN         NaN         NaN         NaN  ...      -3.526294
#
#       LogProba_3_sql  LogProba_4_sql  LogProba_5_sql  LogProba_6_sql  \
# 1197       -2.185342       -3.074713       -1.532286       -3.913458
# 913        -2.097181       -3.883939       -2.617019       -3.047992
# 893        -2.486125       -4.001539       -0.718490       -4.412884
# 604        -4.182968       -2.009558       -1.538349       -1.123425
# 743        -5.425719       -0.615005       -3.479554       -4.037963
# 556        -2.412699       -3.587378       -4.484135       -2.869010
# 664        -2.387851       -3.237153       -2.289746       -2.790281
# 195        -4.971824       -3.079982       -4.108785       -0.226434
# 692        -3.617052       -3.603747       -0.359531       -3.612624
# 1589       -4.513059       -3.068721       -0.702351       -2.655061
# 1194       -2.567681       -4.120463       -2.611717       -4.634110
# 822        -3.807369       -3.652604       -0.363653       -4.745843
#
#       LogProba_7_sql  LogProba_8_sql  LogProba_9_sql  Decision_sql  \
# 1197       -2.400581       -1.469503       -2.246424             8
# 913        -3.786127       -0.820853       -2.183164             8
# 893        -3.060126       -2.164634       -2.968205             5
# 604        -3.581279       -2.308723       -4.636519             6
# 743        -1.379316       -3.507207       -3.300613             4
# 556        -3.602473       -0.967115       -3.418996             8
# 664        -3.369948       -0.969122       -2.358257             8
# 195        -5.803139       -3.301036       -5.121011             6
# 692        -3.345042       -2.542779       -3.533635             5
# 1589       -2.595765       -2.939838       -3.168150             5
# 1194       -3.696028       -2.798969       -0.443228             9
# 822        -2.786068       -2.546733       -3.290512             5
#
#       DecisionProba
# 1197       0.230040
# 913        0.440056
# 893        0.487488
# 604        0.325164
# 743        0.540638
# 556        0.380178
# 664        0.379416
# 195        0.797372
# 692        0.698004
# 1589       0.495419
# 1194       0.641961
# 822        0.695132
#
# [12 rows x 65 columns]

# %%
condition = (sql_skl_join.Decision_sql != sql_skl_join.Decision_skl)
sql_skl_join[condition]
# Out:
# Empty DataFrame
# Columns: [KEY_skl, Score_0_skl, Score_1_skl, Score_2_skl, Score_3_skl, Score_4_skl, Score_5_skl, Score_6_skl, Score_7_skl, Score_8_skl, Score_9_skl, Proba_0_skl, Proba_1_skl, Proba_2_skl, Proba_3_skl, Proba_4_skl, Proba_5_skl, Proba_6_skl, Proba_7_skl, Proba_8_skl, Proba_9_skl, LogProba_0_skl, LogProba_1_skl, LogProba_2_skl, LogProba_3_skl, LogProba_4_skl, LogProba_5_skl, LogProba_6_skl, LogProba_7_skl, LogProba_8_skl, LogProba_9_skl, Decision_skl, KEY_sql, Score_0_sql, Score_1_sql, Score_2_sql, Score_3_sql, Score_4_sql, Score_5_sql, Score_6_sql, Score_7_sql, Score_8_sql, Score_9_sql, Proba_0_sql, Proba_1_sql, Proba_2_sql, Proba_3_sql, Proba_4_sql, Proba_5_sql, Proba_6_sql, Proba_7_sql, Proba_8_sql, Proba_9_sql, LogProba_0_sql, LogProba_1_sql, LogProba_2_sql, LogProba_3_sql, LogProba_4_sql, LogProba_5_sql, LogProba_6_sql, LogProba_7_sql, LogProba_8_sql, LogProba_9_sql, Decision_sql, DecisionProba]
# Index: []
#
# [0 rows x 65 columns]
